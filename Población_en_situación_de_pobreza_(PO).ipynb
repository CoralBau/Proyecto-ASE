# %% [markdown]
# <a href="https://colab.research.google.com/github/CoralBau/Proyecto-ASE/blob/Pobreza/Poblaci%C3%B3n_en_situaci%C3%B3n_de_pobreza_(PO).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nombre: Coral Alejandra Bautista Calva
#Carrera: Actuaría
#Asesor: Dr. Nelson Omar Muriel Torrero
#Lector: Dr. Gabriela Andrea Luna Ruíz
#Lector: Dr. Lazaro Bustio Martinez
#Institución: Universidad Iberoamericana
#Matrícula: 215055-5
#Fecha: 16/11/2022
#Objetivos: Este programa contiene datos generales, matriz de correlación, gráficas lineales y gráficas de barras 
#de todos los estados por año (2008-2010,2012-2014-2016-2018-2020) y una en donde se comparan todos los años juntos
#de la población en situación de pobreza en México


import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import io as io

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-33ab8552-fc97-4efb-aca3-04ab7c035334" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33ab8552-fc97-4efb-aca3-04ab7c035334">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Datos Generales

# %%
po = pd.read_csv(io.BytesIO(uploaded['Población en situación de pobreza.csv']), encoding="utf8")
po
# Out:
#                  Entidad Federativa  Porcentaje 2008  Porcentaje 2010  \
# 0                    Aguascalientes             37.6             38.1
# 1                   Baja California             26.0             31.5
# 2               Baja California Sur             21.4             31.0
# 3                          Campeche             45.9             50.5
# 4              Coahuila de Zaragoza             32.7             27.8
# 5                            Colima             27.4             34.7
# 6                           Chiapas             77.0             78.5
# 7                         Chihuahua             32.1             38.8
# 8                  Ciudad de México             27.6             28.5
# 9                           Durango             48.4             51.6
# 10                       Guanajuato             44.1             48.5
# 11                         Guerrero             68.4             67.6
# ...

# %% [markdown]
# Matriz de correlación entre los porcentajes de cada año

# %%
po.corr()
# Out:
#                  Porcentaje 2008  Porcentaje 2010  Porcentaje 2012  \
# Porcentaje 2008         1.000000         0.962426         0.978236
# Porcentaje 2010         0.962426         1.000000         0.970954
# Porcentaje 2012         0.978236         0.970954         1.000000
# Porcentaje 2014         0.967185         0.956148         0.968744
# Porcentaje 2016         0.960413         0.955185         0.952183
# Porcentaje 2018         0.948228         0.944715         0.935196
# Porcentaje 2020         0.915834         0.893336         0.902857
#
#                  Porcentaje 2014  Porcentaje 2016  Porcentaje 2018  \
# Porcentaje 2008         0.967185         0.960413         0.948228
# Porcentaje 2010         0.956148         0.955185         0.944715
# Porcentaje 2012         0.968744         0.952183         0.935196
# Porcentaje 2014         1.000000         0.978187         0.954439
# Porcentaje 2016         0.978187         1.000000         0.981421
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(po.corr(), annot=True, fmt='.2f')

# %% [markdown]
# Gráficas de líneas por año y la comparación de todos los años juntos

# %%
#Porcentaje de población en situación de pobreza de 2008 por estados
plt.figure(figsize=(40, 10))

plt.plot(po['Entidad Federativa'], po['Porcentaje 2008'], label='Porcentaje 2008')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de pobreza', fontsize=30) 
plt.title('Porcentaje 2008', fontsize=40) 

plt.axhline(y=44.4, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2010 por estados
plt.figure(figsize=(40, 10))

plt.plot(po['Entidad Federativa'], po['Porcentaje 2010'], label='Porcentaje 2010')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de pobreza', fontsize=30) 
plt.title('Porcentaje 2010', fontsize=40) 

plt.axhline(y=46.1, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2012 por estados
plt.figure(figsize=(40, 10))

plt.plot(po['Entidad Federativa'], po['Porcentaje 2012'], label='Porcentaje 2012')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de pobreza', fontsize=30) 
plt.title('Porcentaje 2012', fontsize=40) 

plt.axhline(y=45.5, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2014 por estados
plt.figure(figsize=(40, 10))

plt.plot(po['Entidad Federativa'], po['Porcentaje 2014'], label='Porcentaje 2014')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de pobreza', fontsize=30) 
plt.title('Porcentaje 2014', fontsize=40) 

plt.axhline(y=46.2, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2016 por estados
plt.figure(figsize=(40, 10))

plt.plot(po['Entidad Federativa'], po['Porcentaje 2016'], label='Porcentaje 2016')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de pobreza', fontsize=30) 
plt.title('Porcentaje 2016', fontsize=40) 

plt.axhline(y=43.2, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2018 por estados
plt.figure(figsize=(40, 10))

plt.plot(po['Entidad Federativa'], po['Porcentaje 2018'], label='Porcentaje 2018')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de pobreza', fontsize=30) 
plt.title('Porcentaje 2018', fontsize=40) 

plt.axhline(y=41.9, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2020 por estados
plt.figure(figsize=(40, 10))

plt.plot(po['Entidad Federativa'], po['Porcentaje 2020'], label='Porcentaje 2020')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de pobreza', fontsize=30) 
plt.title('Porcentaje 2020', fontsize=40) 

plt.axhline(y=43.9, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2008 a 2020 por estados
plt.figure(figsize=(40, 10))

plt.plot(po['Entidad Federativa'], po['Porcentaje 2008'], label='Porcentaje 2008')
plt.plot(po['Entidad Federativa'], po['Porcentaje 2010'], label='Porcentaje 2010')
plt.plot(po['Entidad Federativa'], po['Porcentaje 2012'], label='Porcentaje 2012')
plt.plot(po['Entidad Federativa'], po['Porcentaje 2014'], label='Porcentaje 2014')
plt.plot(po['Entidad Federativa'], po['Porcentaje 2016'], label='Porcentaje 2016')
plt.plot(po['Entidad Federativa'], po['Porcentaje 2018'], label='Porcentaje 2018')
plt.plot(po['Entidad Federativa'], po['Porcentaje 2020'], label='Porcentaje 2020')

plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de pobreza', fontsize=30) 
plt.title('Porcentaje 2008-2020', fontsize=40) 

plt.axhline(y=44.4, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# Gráfica de Barras por año

# %%
#Porcentaje de población en situación de pobreza de 2008 por estados
entidad = po["Entidad Federativa"]
percent = po["Porcentaje 2008"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Pobreza 2008',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2008')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=44.4 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2010 por estados
entidad = po["Entidad Federativa"]
percent = po["Porcentaje 2010"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Pobreza 2010',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2010')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=46.1 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2012 por estados
entidad = po["Entidad Federativa"]
percent = po["Porcentaje 2012"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Pobreza 2012',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2012')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=45.5 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2014 por estados
entidad = po["Entidad Federativa"]
percent = po["Porcentaje 2014"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Pobreza 2014',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2014')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=46.2 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2016 por estados
entidad = po["Entidad Federativa"]
percent = po["Porcentaje 2016"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Pobreza 2016',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2016')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=43.2 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2018 por estados
entidad = po["Entidad Federativa"]
percent = po["Porcentaje 2018"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Pobreza 2018',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2018')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=41.9 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Porcentaje de población en situación de pobreza de 2020 por estados
entidad = po["Entidad Federativa"]
percent = po["Porcentaje 2020"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Pobreza 2020',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2020')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=43.9 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

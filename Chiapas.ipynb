# %% [markdown]
# <a href="https://colab.research.google.com/github/CoralBau/Proyecto-ASE/blob/Chiapas/Chiapas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nombre: Coral Alejandra Bautista Calva
#Carrera: Actuaría
#Asesor: Dr. Nelson Omar Muriel Torrero
#Lector: Dr. Gabriela Andrea Luna Ruíz
#Lector: Dr. Lazaro Bustio Martinez
#Institución: Universidad Iberoamericana
#Matrícula: 215055-5
#Fecha: 16/11/2022
#Objetivos: Este programa contine datos generales, gráficas lineales y gráficas de barras sobrepuestas de la comparación entre los estados de Chiapas, Nuevo León y Ciudad de México 
#en los rubros de rezago educativo, pobreza, carencias sociales y educación superior en los años propuestos anteriormente (2008-2010,2012-2014-2016-2018-2020)
#y también contiene una sección donde se comparan los mismos rubros pero solo dentro del estado de Chiapas y la correlación entre ellos


import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import io as io

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12678884-989e-43dd-ac44-305bc157f6b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12678884-989e-43dd-ac44-305bc157f6b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Datos Generales

# %%
df = pd.read_csv(io.BytesIO(uploaded['Chiapas.csv']), encoding="utf8")
df
# Out:
#     Año  Chiapas re  Nuevo León re  Ciudad de México re  Chiapas po  \
# 0  2008        38.0           15.0                 10.6        77.0
# 1  2010        35.0           13.1                  9.5        78.5
# 2  2012        33.5           12.7                  9.2        74.7
# 3  2014        30.7           10.8                  8.8        76.2
# 4  2016        30.2           12.2                  8.9        77.9
# 5  2018        31.2           13.4                  9.4        78.0
# 6  2020        32.5           14.4                  9.5        75.5
#
#    Nuevo León po  Ciudad de México po  Chiapas cs  Nuevo León cs  \
# 0           21.4                 27.6        15.9           36.5
# 1           21.0                 28.5        13.0           31.6
# 2           23.2                 28.9        17.2           29.1
# 3           20.4                 28.4        15.3           28.0
# 4           18.8                 26.6        11.8           28.0
# ...

# %% [markdown]
# Gráficas de líneas

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Año'], df['Chiapas re'], label='Chiapas re') 
plt.plot(df['Año'], df['Nuevo León re'], label='Nuevo León re') 
plt.plot(df['Año'], df['Ciudad de México re'], label='Ciudad de México re')
plt.xlabel('Año')
plt.ylabel('Porcentaje') 
plt.title('Rezago Educativo') 
plt.grid(True)
plt.legend()

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Año'], df['Chiapas po'], label='Chiapas po') 
plt.plot(df['Año'], df['Nuevo León po'], label='Nuevo León po') 
plt.plot(df['Año'], df['Ciudad de México po'], label='Ciudad de México po')
plt.xlabel('Año')
plt.ylabel('Porcentaje') 
plt.title('Pobreza') 
plt.grid(True)
plt.legend()

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Año'], df['Chiapas cs'], label='Chiapas cs') 
plt.plot(df['Año'], df['Nuevo León cs'], label='Nuevo León cs') 
plt.plot(df['Año'], df['Ciudad de México cs'], label='Ciudad de México cs')
plt.xlabel('Año')
plt.ylabel('Porcentaje') 
plt.title('Carencias Sociales') 
plt.grid(True)
plt.legend()
#Congruente con el tamaño de la población
#POBLACIÓN VULNERABLE POR CARENCIAS SOCIALES

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Año'], df['Chiapas es'], label='Chiapas es') 
plt.plot(df['Año'], df['Nuevo León es'], label='Nuevo León es') 
plt.plot(df['Año'], df['Ciudad de México es'], label='Ciudad de México es')
plt.xlabel('Año')
plt.ylabel('Porcentaje') 
plt.title('Educación Superior') 
plt.grid(True)
plt.legend()

# %% [markdown]
# Gráficas de barras sobrepuestas

# %%
data1= df["Chiapas re"]
data2= df["Nuevo León re"]
data3= df["Ciudad de México re"]
year= df["Año"]

plt.figure(figsize=(15,5))

plt.bar(year,data3,color=["#3f3e6fd1"],label="Ciudad de México re")
plt.bar(year,data2,color = ['#eed4d0'],bottom=np.array(data3),label="Nuevo León re")
plt.bar(year,data1,color=["#85c6a9"],bottom=np.array(data3)+np.array(data2),label="Chiapas re")
plt.xlabel('Año')
plt.ylabel('Porcentaje') 
plt.title('Rezago Educativo') 

plt.legend()

plt.legend(loc="lower left",bbox_to_anchor=(0.8,1.0))
plt.show()

# %%
data1= df["Chiapas po"]
data2= df["Nuevo León po"]
data3= df["Ciudad de México po"]
year= df["Año"]

plt.figure(figsize=(15,5))

plt.bar(year,data3,color=["#3f3e6fd1"],label="Ciudad de México po")
plt.bar(year,data2,color = ['#eed4d0'],bottom=np.array(data3),label="Nuevo León po")
plt.bar(year,data1,color=["#85c6a9"],bottom=np.array(data3)+np.array(data2),label="Chiapas po")
plt.xlabel('Año')
plt.ylabel('Porcentaje') 
plt.title('Pobreza') 

plt.legend()

plt.legend(loc="lower left",bbox_to_anchor=(0.8,1.0))
plt.show()

# %%
data1= df["Chiapas cs"]
data2= df["Nuevo León cs"]
data3= df["Ciudad de México cs"]
year= df["Año"]

plt.figure(figsize=(15,5))

plt.bar(year,data3,color=["#3f3e6fd1"],label="Ciudad de México cs")
plt.bar(year,data2,color = ['#eed4d0'],bottom=np.array(data3),label="Nuevo León cs")
plt.bar(year,data1,color=["#85c6a9"],bottom=np.array(data3)+np.array(data2),label="Chiapas cs")
plt.xlabel('Año')
plt.ylabel('Porcentaje') 
plt.title('Carencias Sociales') 

plt.legend()

plt.legend(loc="lower left",bbox_to_anchor=(0.8,1.0))
plt.show()

# %%
data1= df["Chiapas es"]
data2= df["Nuevo León es"]
data3= df["Ciudad de México es"]
year= df["Año"]

plt.figure(figsize=(15,5))

plt.bar(year,data3,color=["#3f3e6fd1"],label="Ciudad de México es")
plt.bar(year,data2,color = ['#eed4d0'],bottom=np.array(data3),label="Nuevo León es")
plt.bar(year,data1,color=["#85c6a9"],bottom=np.array(data3)+np.array(data2),label="Chiapas es")
plt.xlabel('Año')
plt.ylabel('Porcentaje') 
plt.title('Educación Superior') 

plt.legend()

plt.legend(loc="lower left",bbox_to_anchor=(0.8,1.0))
plt.show()

# %% [markdown]
# Solo Chiapas

# %% [markdown]
# Gráfica de barras comparativas

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(20, 6))
 
# set height of bar
d1 = df["Chiapas po"]
d2 = df["Chiapas re"]
d3 = df["Chiapas cs"]
d4 = df["Chiapas es"]
 
# Set position of bar on X axis
br1 = np.arange(len(d1))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
 
# Make the plot
plt.bar(br1, d1, color ='#cda0aa', width = barWidth,
        edgecolor ='grey', label ='Pobreza')
plt.bar(br2, d2, color ="#85c6a9", width = barWidth,
        edgecolor ='grey', label ='Rezago educativo')
plt.bar(br3, d3, color ='#eed4d0', width = barWidth,
        edgecolor ='grey', label ='Carencia social')
plt.bar(br4, d4, color = "#3f3e6fd1", width = barWidth,
        edgecolor ='grey', label ='Educación superior')
 
# Adding Xticks
plt.title('Chiapas',fontsize= 14)
plt.xlabel('Año', fontweight ='bold', fontsize = 15)
plt.ylabel('Porcentaje', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(d1))],
        df['Año'])
 
plt.legend()
plt.show()

# %% [markdown]
# Gráfica de líneas comparativas

# %%
plt.figure(figsize=(15, 5))

plt.plot(df['Año'], df['Chiapas po'], label='Chiapas po')
plt.plot(df['Año'], df['Chiapas re'], label='Chiapas re')
plt.plot(df['Año'], df['Chiapas cs'], label='Chiapas cs')
plt.plot(df['Año'], df['Chiapas es'], label='Chiapas es')

plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Año', fontsize=30)
plt.ylabel('Porcentaje', fontsize=30) 
plt.title('Chiapas', fontsize=40) 


plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# Gráfica de barras horizontal

# %%
name = df['Chiapas re'].head(12)
price = df['Año'].head(12)

# Figure Size
fig, ax = plt.subplots(figsize =(15, 5))
 
# Horizontal Bar Plot
ax.barh(price,name)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 2)
ax.yaxis.set_tick_params(pad = 7)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
    

 
# Add Plot Title
plt.title('Rezago Educativo ',fontsize= 14)
plt.xlabel('Porcentaje')
plt.ylabel('Año')
plt.xticks(rotation=0, horizontalalignment='right',fontweight='light')


# Show Plot
plt.grid(True)


plt.show()

# %%
name = df['Chiapas po'].head(12)
price = df['Año'].head(12)

# Figure Size
fig, ax = plt.subplots(figsize =(15, 5))
 
# Horizontal Bar Plot
ax.barh(price,name)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 2)
ax.yaxis.set_tick_params(pad = 7)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
    

 
# Add Plot Title
plt.title('Pobreza',fontsize= 14)
plt.xlabel('Porcentaje')
plt.ylabel('Año')
plt.xticks(rotation=0, horizontalalignment='right',fontweight='light')


# Show Plot
plt.grid(True)


plt.show()

# %%
name = df['Chiapas cs'].head(12)
price = df['Año'].head(12)

# Figure Size
fig, ax = plt.subplots(figsize =(15, 5))
 
# Horizontal Bar Plot
ax.barh(price,name)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 2)
ax.yaxis.set_tick_params(pad = 7)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
    

 
# Add Plot Title
plt.title('Carencias Sociales',fontsize= 14)
plt.xlabel('Porcentaje')
plt.ylabel('Año')
plt.xticks(rotation=0, horizontalalignment='right',fontweight='light')


# Show Plot
plt.grid(True)


plt.show()

# %%
name = df['Chiapas es'].head(12)
price = df['Año'].head(12)

# Figure Size
fig, ax = plt.subplots(figsize =(15, 5))
 
# Horizontal Bar Plot
ax.barh(price,name)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 2)
ax.yaxis.set_tick_params(pad = 7)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
    

 
# Add Plot Title
plt.title('Educación Superior',fontsize= 14)
plt.xlabel('Porcentaje')
plt.ylabel('Año')
plt.xticks(rotation=0, horizontalalignment='right',fontweight='light')


# Show Plot
plt.grid(True)


plt.show()

# %% [markdown]
# Datos sin la columna de año

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dde1be5e-f772-4dd6-aa6e-5695463510a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dde1be5e-f772-4dd6-aa6e-5695463510a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2 = pd.read_csv(io.BytesIO(uploaded['Chiapas sin año.csv']), encoding="utf8")
df2
# Out:
#    Chiapas re  Chiapas po  Chiapas cs  Chiapas es
# 0        38.0        77.0        15.9       13.41
# 1        35.0        78.5        13.0       13.68
# 2        33.5        74.7        17.2       14.49
# 3        30.7        76.2        15.3       14.49
# 4        30.2        77.9        11.8       15.32
# 5        31.2        78.0        12.3       14.86
# 6        32.5        75.5        14.1       14.37

# %%
df2.corr()
# Out:
#             Chiapas re  Chiapas po  Chiapas cs  Chiapas es
# Chiapas re    1.000000    0.005837    0.460667   -0.915547
# Chiapas po    0.005837    1.000000   -0.793173   -0.010226
# Chiapas cs    0.460667   -0.793173    1.000000   -0.449583
# Chiapas es   -0.915547   -0.010226   -0.449583    1.000000

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df2.corr(), annot=True, fmt='.2f')

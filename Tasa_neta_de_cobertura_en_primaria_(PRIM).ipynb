# %% [markdown]
# <a href="https://colab.research.google.com/github/CoralBau/Proyecto-ASE/blob/Primaria/Tasa_neta_de_cobertura_en_primaria_(PRIM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nombre: Coral Alejandra Bautista Calva
#Carrera: Actuaría
#Asesor: Dr. Nelson Omar Muriel Torrero
#Lector: Dr. Gabriela Andrea Luna Ruíz
#Lector: Dr. Lazaro Bustio Martinez
#Institución: Universidad Iberoamericana
#Matrícula: 215055-5
#Fecha: 16/11/2022
#Objetivos: Este programa contiene datos generales, matriz de correlación, gráficas lineales y gráficas de barras 
#de todos los estados por año (2008-2010,2012-2014-2016-2018-2020) y una en donde se comparan todos los años juntos
#de la tasa neta de cobertura en primaria en México


import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import io as io

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bcf2cc88-d587-40df-9d40-42adcff66111" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bcf2cc88-d587-40df-9d40-42adcff66111">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Datos Generales

# %%
prim = pd.read_csv(io.BytesIO(uploaded['Tasa neta de cobertura en primaria.csv']), encoding="utf8")
prim
# Out:
#                  Entidad Federativa  Porcentaje 2008 (6-11 años)  \
# 0                    Aguascalientes                        97.06
# 1                   Baja California                       104.35
# 2               Baja California Sur                       105.03
# 3                          Campeche                        97.24
# 4              Coahuila de Zaragoza                       108.67
# 5                            Colima                        92.98
# 6                           Chiapas                       102.67
# 7                         Chihuahua                        98.37
# 8                  Ciudad de México                       103.80
# 9                           Durango                       101.22
# 10                       Guanajuato                       102.68
# 11                         Guerrero                       102.04
# 12                          Hidalgo                        98.78
# ...

# %% [markdown]
# Matriz de correlación de los porcentajes de cada año

# %%
prim.corr()
# Out:
#                              Porcentaje 2008 (6-11 años)  \
# Porcentaje 2008 (6-11 años)                     1.000000
# Porcentaje 2010 (6-11 años)                     0.814243
# Porcentaje 2012 (6-11 años)                     0.637318
# Porcentaje 2014 (6-11 años)                     0.241127
# Porcentaje 2016 (6-11 años)                     0.334958
# Porcentaje 2018 (6-11 años)                     0.421921
# Porcentaje 2020 (6-11 años)                     0.442982
#
#                              Porcentaje 2010 (6-11 años)  \
# Porcentaje 2008 (6-11 años)                     0.814243
# Porcentaje 2010 (6-11 años)                     1.000000
# Porcentaje 2012 (6-11 años)                     0.822324
# Porcentaje 2014 (6-11 años)                     0.371895
# Porcentaje 2016 (6-11 años)                     0.367141
# Porcentaje 2018 (6-11 años)                     0.393361
# Porcentaje 2020 (6-11 años)                     0.444449
#
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(prim.corr(), annot=True, fmt='.2f')

# %% [markdown]
# Gráficas de líneas por año y la comparación de todos los años juntos

# %%
#Tasa neta de cobertura en primaria de 2008 por estados
plt.figure(figsize=(40, 10))

plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2008 (6-11 años)'], label='Porcentaje 2008 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de cobertura en primaria', fontsize=30) 
plt.title('Porcentaje 2008 (6-11 años)', fontsize=40) 

plt.axhline(y=100.84, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Tasa neta de cobertura en primaria de 2010 por estados
plt.figure(figsize=(40, 10))

plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2010 (6-11 años)'], label='Porcentaje 2010 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de cobertura en primaria', fontsize=30) 
plt.title('Porcentaje 2010 (6-11 años)', fontsize=40) 

plt.axhline(y=101.66, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Tasa neta de cobertura en primaria de 2012 por estados
plt.figure(figsize=(40, 10))

plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2012 (6-11 años)'], label='Porcentaje 2012 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de cobertura en primaria', fontsize=30) 
plt.title('Porcentaje 2012 (6-11 años)', fontsize=40) 

plt.axhline(y=100.69, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Tasa neta de cobertura en primaria de 2014 por estados
plt.figure(figsize=(40, 10))

plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2014 (6-11 años)'], label='Porcentaje 2014 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de cobertura en primaria', fontsize=30) 
plt.title('Porcentaje 2014 (6-11 años)', fontsize=40) 

plt.axhline(y=98.74, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Tasa neta de cobertura en primaria de 2016 por estados
plt.figure(figsize=(40, 10))

plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2016 (6-11 años)'], label='Porcentaje 2016 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de cobertura en primaria', fontsize=30) 
plt.title('Porcentaje 2016 (6-11 años)', fontsize=40) 

plt.axhline(y=98.45, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Tasa neta de cobertura en primaria de 2018 por estados
plt.figure(figsize=(40, 10))

plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2018 (6-11 años)'], label='Porcentaje 2018 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de cobertura en primaria', fontsize=30) 
plt.title('Porcentaje 2018 (6-11 años)', fontsize=40) 

plt.axhline(y=98.66, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Tasa neta de cobertura en primaria de 2020 por estadoss
plt.figure(figsize=(40, 10))

plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2020 (6-11 años)'], label='Porcentaje 2020 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de cobertura en primaria', fontsize=30) 
plt.title('Porcentaje 2020 (6-11 años)', fontsize=40) 

plt.axhline(y=97.37, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %%
#Tasa neta de cobertura en primaria de 2008 a 2020 por estados
plt.figure(figsize=(40, 10))

plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2008 (6-11 años)'], label='Porcentaje 2008 (6-11 años)')
plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2010 (6-11 años)'], label='Porcentaje 2010 (6-11 años)')
plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2012 (6-11 años)'], label='Porcentaje 2012 (6-11 años)')
plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2014 (6-11 años)'], label='Porcentaje 2014 (6-11 años)')
plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2016 (6-11 años)'], label='Porcentaje 2016 (6-11 años)')
plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2018 (6-11 años)'], label='Porcentaje 2018 (6-11 años)')
plt.plot(prim['Entidad Federativa'], prim['Porcentaje 2020 (6-11 años)'], label='Porcentaje 2020 (6-11 años)')

plt.xticks(rotation=45, horizontalalignment='right',fontweight='light', fontsize=20)
plt.xlabel('Entidad Federativa', fontsize=30)
plt.ylabel('Porcentaje de cobertura en primaria', fontsize=30) 
plt.title('Porcentaje 2008-2020', fontsize=40) 

plt.axhline(y=99.48, color='red', linestyle='--', linewidth=3, label='Nacional')

plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# Gráfica de Barras por año

# %%
#Tasa neta de cobertura en primaria de 2008 por estados
entidad = prim["Entidad Federativa"]
percent = prim["Porcentaje 2008 (6-11 años)"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Tasa de cobertura primaria 2008',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2008 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=100.84 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Tasa neta de cobertura en primaria de 2010 por estados
entidad = prim["Entidad Federativa"]
percent = prim["Porcentaje 2010 (6-11 años)"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Tasa de cobertura primaria 2010',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2010 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=101.66 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Tasa neta de cobertura en primaria de 2012 por estados
entidad = prim["Entidad Federativa"]
percent = prim["Porcentaje 2012 (6-11 años)"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Tasa de cobertura primaria 2012',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2012 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=100.69 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Tasa neta de cobertura en primaria de 2014 por estados
entidad = prim["Entidad Federativa"]
percent = prim["Porcentaje 2014 (6-11 años)"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Tasa de cobertura primaria 2014',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2014 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=98.74 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Tasa neta de cobertura en primaria de 2016 por estados
entidad = prim["Entidad Federativa"]
percent = prim["Porcentaje 2016 (6-11 años)"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Tasa de cobertura primaria 2016',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2016 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=98.45 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Tasa neta de cobertura en primaria de 2018 por estados
entidad = prim["Entidad Federativa"]
percent = prim["Porcentaje 2018 (6-11 años)"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Tasa de cobertura primaria 2018',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2018 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=98.37 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()

# %%
#Tasa neta de cobertura en primaria de 2020 por estados
entidad = prim["Entidad Federativa"]
percent = prim["Porcentaje 2020 (6-11 años)"]

# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Tasa de cobertura primaria 2020',fontsize= 14)
plt.xlabel('Entidad Federativa')
plt.ylabel('Porcentaje 2020 (6-11 años)')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

# Horizontal Bar Plot
plt.bar(entidad, percent)
nacional = [7 for i in range(33)] 

plt.axhline(y=97.37 , color='red', linestyle='--', linewidth=3, label='Nacional')

# Show Plot
plt.show()
